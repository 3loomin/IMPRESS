# %%
import numpy as np
import torch
import librosa
import pandas
import matplotlib.pyplot as plt
import scipy.io.wavfile
import os

# %%
wav='../Data/example.wav'
(file_dir, file_id) = os.path.split(wav)
print("file_dir:", file_dir)
print("file_id:", file_id)
data, sr = librosa.load(wav, sr=16000)
# Out:
# file_dir: ../Data
# file_id: example.wav

# %%
data
# Out:
# array([0.00109863, 0.00112915, 0.00183105, ..., 0.00021362, 0.00027466,
#        0.00024414], dtype=float32)

# %%
len(data)
# Out:
# 183280

# %%
len(data)/sr
# Out:
# 11.455

# %%
import IPython.display as ipd
ipd.Audio(data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y_8k=librosa.resample(data,sr,8000)
ipd.Audio(y_8k,rate=8000)
len(y_8k)
# Out:
# 91640

# %%
y_2k=librosa.resample(data,sr,4000)
ipd.Audio(y_2k,rate=2000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(y_2k)
# Out:
# 45820

# %%
normed_wav=data/max(np.abs(data))
ipd.Audio(normed_wav,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Bit = 8 
max_value = 2**(Bit-1)
quantized_8_wav=normed_wav*max_value
quantized_8_wav=np.round(quantized_8_wav).astype(int)
quantized_8_wav=np.clip(quantized_8_wav, -max_value,max_value-1)
ipd.Audio(quantized_8_wav,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def mu_law(x,mu=255):
    return np.sign(x)*np.log(1+mu*np.abs(x))/np.log(1+mu)

# %%
x=np.linspace(-1,1,1000)
x_mu=mu_law(x)

plt.figure(figsize=[8,4])
plt.plot(x)
plt.plot(x_mu)
plt.show()

# %%
wav_mulaw=mu_law(normed_wav)
ipd.Audio(wav_mulaw,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa.display
fig = plt.figure(figsize=(14,5))
librosa.display.waveplot(data[0:100000],sr=sr)

# %%
A=0.9
f=340 #라
phi=np.pi/2
fs=22050
t=1

# %%
def Sinusoid(A,f,phi,fs,t):
    t=np.arange(0,t,1.0/fs)
    x=A*np.cos(2*np.pi*f*t+phi)
    return x

# %%
sin2=Sinusoid(A,f,phi,fs,t)

# %%
fig=plt.figure(figsize=(14,5))
librosa.display.waveplot(sin2[:1000],sr=fs)

# %%
A=0.9
D=587
phi=np.pi/2
fs=22050
t=1

# %%
sin=Sinusoid(A,D,phi,fs,t)

# %%
complexwave=sin+sin2

# %%
ipd.Audio(sin+sin2,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
